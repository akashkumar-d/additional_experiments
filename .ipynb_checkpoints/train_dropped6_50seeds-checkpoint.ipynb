# %% [markdown]
# # Train the 6 dropped-from-grid configurations to the full seed count
#
# The submitted Figure 3(d) uses 15 configurations; 6 of them were dropped when
# the 33-grid was revised, so the 50-seed rerun skipped them. This notebook
# brings exactly those 6 up to the same seed list (parsed from
# `item1_all33_seeds.ipynb`), writing into the same `item1_all33/` folder with
# the same runner, steps and logging — so `fig3d_15configs.ipynb` picks them up
# with no changes. Restart-safe: existing checkpoints are skipped.

# %%
import ast, json, re, sys, time
from pathlib import Path

WORKDIR = Path('.').resolve()
sys.path.insert(0, str(WORKDIR / 'shared'))
OUT = WORKDIR / 'item1_all33'; OUT.mkdir(exist_ok=True)

_nb = json.loads((WORKDIR / 'item1_all33_seeds.ipynb').read_text())
_src = next(''.join(c['source']) for c in _nb['cells'] if 'SEEDS = [' in ''.join(c['source']))
_lit = _src[_src.index('SEEDS = ['):]
SEEDS = ast.literal_eval(_lit[_lit.index('['):_lit.index(']') + 1])
N_STEPS, LOG_EVERY, N = 8000, 20, 15000

# the 6 configurations of the submitted figure that the revised grid dropped
DROPPED6 = [  # (gid, teacher, p, r_t, r_s, n, eta)
    ('X1', 'relu', 100, 16, 50, N, 2.0),
    ('X2', 'gelu', 100,  4, 50, N, 0.7),
    ('X3', 'gelu', 100,  8, 50, N, 0.7),
    ('X4', 'gelu', 100, 16, 50, N, 0.7),
    ('X5', 'silu', 100,  4, 50, N, 0.85),
    ('X6', 'silu', 100, 16, 50, N, 0.85),
]
print(f'{len(SEEDS)} seeds x {len(DROPPED6)} configs = {len(SEEDS)*len(DROPPED6)} runs max')
# Out:
# 50 seeds x 6 configs = 300 runs max

# %%
# build the TODO list: only (config, seed) pairs without a finished checkpoint
import numpy as np
RUNS = []
for gid, ta, p, rt, rs, n, eta in DROPPED6:
    have = 0
    for seed in SEEDS:
        ck = OUT / f'{ta}_p{p}_rt{rt}_rs{rs}_n{n}_eta{eta}_seed{seed}.npz'
        if ck.exists():
            try:
                if int(np.load(ck, allow_pickle=True)['next_t']) >= N_STEPS:
                    have += 1; continue
            except Exception:
                pass    # unreadable/partial -> re-run (runner resumes it)
        RUNS.append((gid, ta, p, rt, rs, n, eta, seed))
    print(f'{gid} {ta} rt={rt:>2} eta={eta:<5} complete={have:>2}/{len(SEEDS)}')
print(f'\n{len(RUNS)} runs to do')
# Out:
# X1 relu rt=16 eta=2.0   complete=50/50
# X2 gelu rt= 4 eta=0.7   complete=50/50
# X3 gelu rt= 8 eta=0.7   complete=50/50
# X4 gelu rt=16 eta=0.7   complete=50/50
# X5 silu rt= 4 eta=0.85  complete=38/50
# X6 silu rt=16 eta=0.85  complete=10/50
#
# 52 runs to do

# %%
# multi-machine sharding, same convention as item1_all33_seeds.ipynb
N_PROC      = 4      # worker processes on this machine
WORKER_ID   = 0      # 0 .. NUM_WORKERS-1, unique per machine
NUM_WORKERS = 1
MY_RUNS = [r for i, r in enumerate(RUNS) if i % NUM_WORKERS == WORKER_ID]
print(f'worker {WORKER_ID}/{NUM_WORKERS}: {len(MY_RUNS)} runs')
# Out:
# worker 0/1: 52 runs

# %%
import multiprocessing as mp
import concurrent.futures as cf
from parallel_worker import run_full

ARGS = [(str(OUT), N_STEPS, LOG_EVERY, gid, ta, p, rt, rs, n, eta, seed)
        for (gid, ta, p, rt, rs, n, eta, seed) in MY_RUNS]
t0 = time.time(); done = 0
with cf.ProcessPoolExecutor(max_workers=N_PROC,
                            mp_context=mp.get_context('fork')) as ex:
    for gid, seed in ex.map(run_full, ARGS):
        done += 1
        el = time.time() - t0
        rem = el / done * (len(ARGS) - done)
        print(f'[{done}/{len(ARGS)}] {gid} seed={seed} done  '
              f'({el/3600:.2f} h elapsed, ~{rem/3600:.2f} h left)', flush=True)
print(f'finished in {(time.time()-t0)/3600:.2f} h')
# Out:
# [init silu eta=0.85] silu_p100_rt4_rs50_n15000_eta0.85_seed269.npz: in-V=0.040[resume] silu_p100_rt4_rs50_n15000_eta0.85_seed257.npz: step 4000
#
# [resume] silu_p100_rt4_rs50_n15000_eta0.85_seed263.npz: step 4000[resume] silu_p100_rt4_rs50_n15000_eta0.85_seed251.npz: step 4000
#
# [done] silu eta=0.85 step=8000 L=1.477 L_te=1.461 L_Vopt=0.1028 in_V=0.396 mean_cos²=0.993
# [init silu eta=0.85] silu_p100_rt4_rs50_n15000_eta0.85_seed271.npz: in-V=0.039
# [done] silu eta=0.85 step=8000 L=1.495 L_te=1.459 L_Vopt=0.1019 in_V=0.388 mean_cos²=0.993
# [1/52] X5 seed=251 done  (0.01 h elapsed, ~0.73 h left)
# [2/52] X5 seed=257 done  (0.01 h elapsed, ~0.36 h left)
# [init silu eta=0.85] silu_p100_rt4_rs50_n15000_eta0.85_seed277.npz: in-V=0.039
# [done] silu eta=0.85 step=4000 L=1.499 L_te=1.465 L_Vopt=0.1025 in_V=0.387 mean_cos²=0.993
# [resume] silu_p100_rt4_rs50_n15000_eta0.85_seed271.npz: step 4000
# [done] silu eta=0.85 step=4000 L=1.493 L_te=1.481 L_Vopt=0.1013 in_V=0.389 mean_cos²=0.993
# [resume] silu_p100_rt4_rs50_n15000_eta0.85_seed277.npz: step 4000
# [done] silu eta=0.85 step=8000 L=1.508 L_te=1.494 L_Vopt=0.1000 in_V=0.388 mean_cos²=0.993
# [3/52] X5 seed=263 done  (0.03 h elapsed, ~0.45 h left)
# [init silu eta=0.85] silu_p100_rt4_rs50_n15000_eta0.85_seed281.npz: in-V=0.041
# [done] silu eta=0.85 step=4000 L=1.520 L_te=1.503 L_Vopt=0.0991 in_V=0.384 mean_cos²=0.993
# [resume] silu_p100_rt4_rs50_n15000_eta0.85_seed269.npz: step 4000
# [done] silu eta=0.85 step=8000 L=1.500 L_te=1.468 L_Vopt=0.1027 in_V=0.387 mean_cos²=0.993
# [init silu eta=0.85] silu_p100_rt4_rs50_n15000_eta0.85_seed283.npz: in-V=0.040
# [done] silu eta=0.85 step=8000 L=1.486 L_te=1.469 L_Vopt=0.1018 in_V=0.390 mean_cos²=0.993
# [init silu eta=0.85] silu_p100_rt4_rs50_n15000_eta0.85_seed293.npz: in-V=0.041
# [done] silu eta=0.85 step=4000 L=1.497 L_te=1.484 L_Vopt=0.0984 in_V=0.390 mean_cos²=0.994
# [resume] silu_p100_rt4_rs50_n15000_eta0.85_seed283.npz: step 4000
# [done] silu eta=0.85 step=4000 L=1.484 L_te=1.469 L_Vopt=0.1008 in_V=0.387 mean_cos²=0.993
# [resume] silu_p100_rt4_rs50_n15000_eta0.85_seed293.npz: step 4000
# [done] silu eta=0.85 step=4000 L=1.484 L_te=1.455 L_Vopt=0.1001 in_V=0.391 mean_cos²=0.994
# [resume] silu_p100_rt4_rs50_n15000_eta0.85_seed281.npz: step 4000
# [done] silu eta=0.85 step=8000 L=1.498 L_te=1.492 L_Vopt=0.0967 in_V=0.390 mean_cos²=0.994
# [init silu eta=0.85] silu_p100_rt4_rs50_n15000_eta0.85_seed307.npz: in-V=0.040
# [done] silu eta=0.85 step=8000 L=1.523 L_te=1.518 L_Vopt=0.1001 in_V=0.382 mean_cos²=0.993
# [4/52] X5 seed=269 done  (0.06 h elapsed, ~0.75 h left)
# [5/52] X5 seed=271 done  (0.06 h elapsed, ~0.58 h left)
# [6/52] X5 seed=277 done  (0.06 h elapsed, ~0.48 h left)
# [init silu eta=0.85] silu_p100_rt4_rs50_n15000_eta0.85_seed311.npz: in-V=0.041
# [done] silu eta=0.85 step=8000 L=1.501 L_te=1.476 L_Vopt=0.0998 in_V=0.384 mean_cos²=0.993
# [init silu eta=0.85] silu_p100_rt4_rs50_n15000_eta0.85_seed313.npz: in-V=0.044
# [done] silu eta=0.85 step=8000 L=1.475 L_te=1.456 L_Vopt=0.1000 in_V=0.391 mean_cos²=0.993
# [7/52] X5 seed=281 done  (0.07 h elapsed, ~0.43 h left)
# [8/52] X5 seed=283 done  (0.07 h elapsed, ~0.37 h left)
# [9/52] X5 seed=293 done  (0.07 h elapsed, ~0.32 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed101.npz: in-V=0.161
# [done] silu eta=0.85 step=4000 L=1.519 L_te=1.494 L_Vopt=0.1025 in_V=0.384 mean_cos²=0.993
# [resume] silu_p100_rt4_rs50_n15000_eta0.85_seed307.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.616 L_te=0.755 L_Vopt=0.4537 in_V=0.641 mean_cos²=0.915
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed101.npz: step 4000
# [done] silu eta=0.85 step=4000 L=1.486 L_te=1.473 L_Vopt=0.1047 in_V=0.390 mean_cos²=0.994
# [resume] silu_p100_rt4_rs50_n15000_eta0.85_seed313.npz: step 4000
# [done] silu eta=0.85 step=8000 L=1.512 L_te=1.496 L_Vopt=0.0988 in_V=0.385 mean_cos²=0.993
# [10/52] X5 seed=307 done  (0.08 h elapsed, ~0.35 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed103.npz: in-V=0.160
# [done] silu eta=0.85 step=8000 L=0.584 L_te=0.718 L_Vopt=0.4292 in_V=0.679 mean_cos²=0.946
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed107.npz: in-V=0.149
# [done] silu eta=0.85 step=8000 L=1.503 L_te=1.496 L_Vopt=0.1011 in_V=0.387 mean_cos²=0.994
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed109.npz: in-V=0.152
# [done] silu eta=0.85 step=4000 L=1.491 L_te=1.484 L_Vopt=0.1030 in_V=0.391 mean_cos²=0.994
# [resume] silu_p100_rt4_rs50_n15000_eta0.85_seed311.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.630 L_te=0.750 L_Vopt=0.5347 in_V=0.620 mean_cos²=0.894
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed103.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.626 L_te=0.835 L_Vopt=0.4950 in_V=0.599 mean_cos²=0.859
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed107.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.620 L_te=0.792 L_Vopt=0.5457 in_V=0.611 mean_cos²=0.886
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed109.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.595 L_te=0.713 L_Vopt=0.4872 in_V=0.659 mean_cos²=0.938
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed113.npz: in-V=0.164
# [done] silu eta=0.85 step=8000 L=0.594 L_te=0.797 L_Vopt=0.4755 in_V=0.635 mean_cos²=0.928
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed127.npz: in-V=0.167
# [done] silu eta=0.85 step=8000 L=0.589 L_te=0.755 L_Vopt=0.4904 in_V=0.649 mean_cos²=0.938
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed131.npz: in-V=0.162
# [done] silu eta=0.85 step=4000 L=0.637 L_te=0.802 L_Vopt=0.5470 in_V=0.607 mean_cos²=0.893
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed113.npz: step 4000
# [done] silu eta=0.85 step=8000 L=1.503 L_te=1.498 L_Vopt=0.1049 in_V=0.389 mean_cos²=0.994
# [11/52] X5 seed=311 done  (0.13 h elapsed, ~0.47 h left)
# [12/52] X5 seed=313 done  (0.13 h elapsed, ~0.42 h left)
# [13/52] X6 seed=101 done  (0.13 h elapsed, ~0.38 h left)
# [14/52] X6 seed=103 done  (0.13 h elapsed, ~0.34 h left)
# [15/52] X6 seed=107 done  (0.13 h elapsed, ~0.31 h left)
# [16/52] X6 seed=109 done  (0.13 h elapsed, ~0.28 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed137.npz: in-V=0.166
# [done] silu eta=0.85 step=4000 L=0.641 L_te=0.799 L_Vopt=0.4696 in_V=0.623 mean_cos²=0.890
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed127.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.619 L_te=0.759 L_Vopt=0.5195 in_V=0.636 mean_cos²=0.913
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed131.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.605 L_te=0.761 L_Vopt=0.5109 in_V=0.646 mean_cos²=0.938
# [17/52] X6 seed=113 done  (0.13 h elapsed, ~0.27 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed139.npz: in-V=0.159
# [done] silu eta=0.85 step=8000 L=0.608 L_te=0.759 L_Vopt=0.4495 in_V=0.663 mean_cos²=0.938
# [18/52] X6 seed=127 done  (0.14 h elapsed, ~0.26 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed149.npz: in-V=0.154
# [done] silu eta=0.85 step=8000 L=0.585 L_te=0.721 L_Vopt=0.4795 in_V=0.672 mean_cos²=0.942
# [19/52] X6 seed=131 done  (0.14 h elapsed, ~0.25 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed151.npz: in-V=0.167
# [done] silu eta=0.85 step=4000 L=0.623 L_te=0.815 L_Vopt=0.4915 in_V=0.610 mean_cos²=0.881
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed139.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.641 L_te=0.849 L_Vopt=0.5143 in_V=0.606 mean_cos²=0.864
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed149.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.593 L_te=0.777 L_Vopt=0.4620 in_V=0.649 mean_cos²=0.930
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed157.npz: in-V=0.156
# [done] silu eta=0.85 step=4000 L=0.625 L_te=0.770 L_Vopt=0.5115 in_V=0.611 mean_cos²=0.898
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed151.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.622 L_te=0.778 L_Vopt=0.5400 in_V=0.621 mean_cos²=0.883
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed137.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.608 L_te=0.812 L_Vopt=0.4684 in_V=0.643 mean_cos²=0.941
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed163.npz: in-V=0.160
# [done] silu eta=0.85 step=4000 L=0.631 L_te=0.784 L_Vopt=0.4957 in_V=0.640 mean_cos²=0.919
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed157.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.590 L_te=0.733 L_Vopt=0.4693 in_V=0.648 mean_cos²=0.936
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed167.npz: in-V=0.155
# [done] silu eta=0.85 step=4000 L=0.615 L_te=0.741 L_Vopt=0.5123 in_V=0.631 mean_cos²=0.904
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed163.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.600 L_te=0.749 L_Vopt=0.4577 in_V=0.678 mean_cos²=0.945
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed173.npz: in-V=0.161
# [done] silu eta=0.85 step=4000 L=0.628 L_te=0.780 L_Vopt=0.5356 in_V=0.604 mean_cos²=0.887
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed167.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.580 L_te=0.704 L_Vopt=0.4804 in_V=0.667 mean_cos²=0.941
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed179.npz: in-V=0.178
# [done] silu eta=0.85 step=8000 L=0.587 L_te=0.738 L_Vopt=0.4922 in_V=0.658 mean_cos²=0.935
# [20/52] X6 seed=137 done  (0.19 h elapsed, ~0.30 h left)
# [21/52] X6 seed=139 done  (0.19 h elapsed, ~0.28 h left)
# [22/52] X6 seed=149 done  (0.19 h elapsed, ~0.26 h left)
# [23/52] X6 seed=151 done  (0.19 h elapsed, ~0.24 h left)
# [24/52] X6 seed=157 done  (0.19 h elapsed, ~0.22 h left)
# [25/52] X6 seed=163 done  (0.19 h elapsed, ~0.21 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed181.npz: in-V=0.161
# [done] silu eta=0.85 step=4000 L=0.630 L_te=0.770 L_Vopt=0.5197 in_V=0.642 mean_cos²=0.925
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed173.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.597 L_te=0.745 L_Vopt=0.4926 in_V=0.641 mean_cos²=0.937
# [26/52] X6 seed=167 done  (0.19 h elapsed, ~0.19 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed191.npz: in-V=0.169
# [done] silu eta=0.85 step=4000 L=0.622 L_te=0.778 L_Vopt=0.4976 in_V=0.630 mean_cos²=0.888
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed179.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.598 L_te=0.730 L_Vopt=0.4779 in_V=0.681 mean_cos²=0.950
# [27/52] X6 seed=173 done  (0.20 h elapsed, ~0.19 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed193.npz: in-V=0.164
# [done] silu eta=0.85 step=4000 L=0.610 L_te=0.779 L_Vopt=0.4724 in_V=0.651 mean_cos²=0.897
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed191.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.591 L_te=0.741 L_Vopt=0.4599 in_V=0.667 mean_cos²=0.943
# [28/52] X6 seed=179 done  (0.21 h elapsed, ~0.18 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed197.npz: in-V=0.157
# [done] silu eta=0.85 step=4000 L=0.646 L_te=0.790 L_Vopt=0.4816 in_V=0.625 mean_cos²=0.902
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed193.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.579 L_te=0.739 L_Vopt=0.4515 in_V=0.688 mean_cos²=0.941
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed199.npz: in-V=0.164
# [done] silu eta=0.85 step=4000 L=0.628 L_te=0.745 L_Vopt=0.5084 in_V=0.657 mean_cos²=0.927
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed181.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.633 L_te=0.769 L_Vopt=0.5325 in_V=0.622 mean_cos²=0.881
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed197.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.614 L_te=0.754 L_Vopt=0.4545 in_V=0.666 mean_cos²=0.943
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed211.npz: in-V=0.166
# [done] silu eta=0.85 step=4000 L=0.628 L_te=0.789 L_Vopt=0.4759 in_V=0.617 mean_cos²=0.898
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed199.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.594 L_te=0.706 L_Vopt=0.4647 in_V=0.693 mean_cos²=0.949
# [29/52] X6 seed=181 done  (0.23 h elapsed, ~0.19 h left)
# [30/52] X6 seed=191 done  (0.23 h elapsed, ~0.17 h left)
# [31/52] X6 seed=193 done  (0.23 h elapsed, ~0.16 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed223.npz: in-V=0.163
# [done] silu eta=0.85 step=8000 L=0.599 L_te=0.730 L_Vopt=0.4779 in_V=0.659 mean_cos²=0.939
# [32/52] X6 seed=197 done  (0.23 h elapsed, ~0.15 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed227.npz: in-V=0.161
# [done] silu eta=0.85 step=4000 L=0.613 L_te=0.775 L_Vopt=0.4308 in_V=0.629 mean_cos²=0.867
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed211.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.593 L_te=0.746 L_Vopt=0.4460 in_V=0.654 mean_cos²=0.938
# [33/52] X6 seed=199 done  (0.24 h elapsed, ~0.14 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed229.npz: in-V=0.155
# [done] silu eta=0.85 step=4000 L=0.617 L_te=0.767 L_Vopt=0.5177 in_V=0.637 mean_cos²=0.879
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed223.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.630 L_te=0.789 L_Vopt=0.4603 in_V=0.608 mean_cos²=0.853
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed227.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.583 L_te=0.737 L_Vopt=0.4123 in_V=0.666 mean_cos²=0.936
# [34/52] X6 seed=211 done  (0.25 h elapsed, ~0.13 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed233.npz: in-V=0.161
# [done] silu eta=0.85 step=4000 L=0.608 L_te=0.762 L_Vopt=0.5115 in_V=0.646 mean_cos²=0.911
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed229.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.587 L_te=0.731 L_Vopt=0.4683 in_V=0.673 mean_cos²=0.948
# [35/52] X6 seed=223 done  (0.26 h elapsed, ~0.13 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed239.npz: in-V=0.164
# [done] silu eta=0.85 step=8000 L=0.597 L_te=0.751 L_Vopt=0.4295 in_V=0.643 mean_cos²=0.934
# [36/52] X6 seed=227 done  (0.26 h elapsed, ~0.12 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed241.npz: in-V=0.148
# [done] silu eta=0.85 step=4000 L=0.631 L_te=0.798 L_Vopt=0.4834 in_V=0.625 mean_cos²=0.908
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed233.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.577 L_te=0.723 L_Vopt=0.4726 in_V=0.683 mean_cos²=0.945
# [37/52] X6 seed=229 done  (0.27 h elapsed, ~0.11 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed251.npz: in-V=0.145
# [done] silu eta=0.85 step=4000 L=0.628 L_te=0.788 L_Vopt=0.4796 in_V=0.652 mean_cos²=0.926
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed239.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.629 L_te=0.783 L_Vopt=0.5088 in_V=0.627 mean_cos²=0.905
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed241.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.599 L_te=0.761 L_Vopt=0.4577 in_V=0.663 mean_cos²=0.942
# [38/52] X6 seed=233 done  (0.28 h elapsed, ~0.10 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed257.npz: in-V=0.180
# [done] silu eta=0.85 step=4000 L=0.606 L_te=0.754 L_Vopt=0.5183 in_V=0.640 mean_cos²=0.907
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed251.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.593 L_te=0.749 L_Vopt=0.4375 in_V=0.688 mean_cos²=0.950
# [39/52] X6 seed=239 done  (0.28 h elapsed, ~0.09 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed263.npz: in-V=0.166
# [done] silu eta=0.85 step=8000 L=0.595 L_te=0.739 L_Vopt=0.4729 in_V=0.665 mean_cos²=0.938
# [40/52] X6 seed=241 done  (0.28 h elapsed, ~0.08 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed269.npz: in-V=0.152
# [done] silu eta=0.85 step=4000 L=0.623 L_te=0.790 L_Vopt=0.5120 in_V=0.615 mean_cos²=0.897
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed257.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.575 L_te=0.719 L_Vopt=0.4741 in_V=0.676 mean_cos²=0.944
# [41/52] X6 seed=251 done  (0.29 h elapsed, ~0.08 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed271.npz: in-V=0.157
# [done] silu eta=0.85 step=4000 L=0.615 L_te=0.784 L_Vopt=0.4606 in_V=0.645 mean_cos²=0.907
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed263.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.645 L_te=0.786 L_Vopt=0.5793 in_V=0.625 mean_cos²=0.909
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed269.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.592 L_te=0.753 L_Vopt=0.4654 in_V=0.652 mean_cos²=0.936
# [42/52] X6 seed=257 done  (0.30 h elapsed, ~0.07 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed277.npz: in-V=0.162
# [done] silu eta=0.85 step=4000 L=0.616 L_te=0.782 L_Vopt=0.4797 in_V=0.628 mean_cos²=0.903
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed271.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.580 L_te=0.737 L_Vopt=0.4231 in_V=0.681 mean_cos²=0.945
# [43/52] X6 seed=263 done  (0.31 h elapsed, ~0.06 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed281.npz: in-V=0.164
# [done] silu eta=0.85 step=8000 L=0.609 L_te=0.747 L_Vopt=0.5073 in_V=0.665 mean_cos²=0.950
# [44/52] X6 seed=269 done  (0.31 h elapsed, ~0.06 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed283.npz: in-V=0.169
# [done] silu eta=0.85 step=4000 L=0.640 L_te=0.771 L_Vopt=0.5238 in_V=0.599 mean_cos²=0.890
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed277.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.586 L_te=0.745 L_Vopt=0.4527 in_V=0.666 mean_cos²=0.938
# [45/52] X6 seed=271 done  (0.32 h elapsed, ~0.05 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed293.npz: in-V=0.162
# [done] silu eta=0.85 step=4000 L=0.626 L_te=0.772 L_Vopt=0.5689 in_V=0.613 mean_cos²=0.860
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed281.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.644 L_te=0.818 L_Vopt=0.4540 in_V=0.621 mean_cos²=0.879
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed283.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.605 L_te=0.731 L_Vopt=0.4922 in_V=0.637 mean_cos²=0.932
# [46/52] X6 seed=277 done  (0.32 h elapsed, ~0.04 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed307.npz: in-V=0.151
# [done] silu eta=0.85 step=4000 L=0.639 L_te=0.796 L_Vopt=0.5326 in_V=0.605 mean_cos²=0.887
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed293.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.594 L_te=0.735 L_Vopt=0.5037 in_V=0.651 mean_cos²=0.940
# [47/52] X6 seed=281 done  (0.33 h elapsed, ~0.04 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed311.npz: in-V=0.157
# [done] silu eta=0.85 step=8000 L=0.611 L_te=0.777 L_Vopt=0.4237 in_V=0.659 mean_cos²=0.943
# [48/52] X6 seed=283 done  (0.33 h elapsed, ~0.03 h left)
# [init silu eta=0.85] silu_p100_rt16_rs50_n15000_eta0.85_seed313.npz: in-V=0.154
# [done] silu eta=0.85 step=4000 L=0.625 L_te=0.756 L_Vopt=0.4612 in_V=0.636 mean_cos²=0.910
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed307.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.605 L_te=0.756 L_Vopt=0.5007 in_V=0.642 mean_cos²=0.938
# [49/52] X6 seed=293 done  (0.34 h elapsed, ~0.02 h left)
# [done] silu eta=0.85 step=4000 L=0.627 L_te=0.789 L_Vopt=0.5369 in_V=0.610 mean_cos²=0.874
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed311.npz: step 4000
# [done] silu eta=0.85 step=4000 L=0.633 L_te=0.755 L_Vopt=0.5228 in_V=0.628 mean_cos²=0.901
# [resume] silu_p100_rt16_rs50_n15000_eta0.85_seed313.npz: step 4000
# [done] silu eta=0.85 step=8000 L=0.591 L_te=0.717 L_Vopt=0.4270 in_V=0.674 mean_cos²=0.945
# [50/52] X6 seed=307 done  (0.35 h elapsed, ~0.01 h left)
# [done] silu eta=0.85 step=8000 L=0.592 L_te=0.749 L_Vopt=0.5007 in_V=0.648 mean_cos²=0.935
# [51/52] X6 seed=311 done  (0.35 h elapsed, ~0.01 h left)
# [done] silu eta=0.85 step=8000 L=0.599 L_te=0.718 L_Vopt=0.4842 in_V=0.666 mean_cos²=0.945
# [52/52] X6 seed=313 done  (0.36 h elapsed, ~0.00 h left)
# finished in 0.36 h

# %% [markdown]
# After this finishes, rerun `fig3d_15configs.ipynb` — its seed table should
# show 50 everywhere and the fits update automatically.
